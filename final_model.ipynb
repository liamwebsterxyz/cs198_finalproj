# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.stats import norm
import pandas_market_calendars as mcal
from scipy import stats

# %%
def bns_jump_test(returns, significance_level=0.01):
    n = len(returns)
    mu = returns.mean(axis=0)
    sigma = returns.std(axis=0)

    z_stat = np.sqrt(n) * (np.abs(mu) - 0.5 * sigma ** 2) / sigma

    critical_value = norm.ppf(1 - significance_level)
    
    return z_stat > critical_value, z_stat, np.argmax(returns)

# %%
def realized_quadratic_variation(returns):
    return np.sum(returns**2)

def realized_bipower_variation(returns, beta=0.5):
    return np.sum(np.abs(returns[:-1]) ** beta * np.abs(returns[1:]) ** beta)

def bns_jump_test2(returns, significance_level=0.01):
    n = len(returns)
    qv = realized_quadratic_variation(returns)
    bv = realized_bipower_variation(returns)
    
    # Test statistic
    mu = (bv / n) * (1 + (2 ** (-1)) * ((8 / (3 * n)) ** 0.5))
    test_stat = (qv - mu * n) / (bv * (1 - (1 / n)) ** (-1))
    
    # Critical value
    critical_value = stats.norm.ppf(1 - significance_level)
    
    # If test_stat > critical_value, we reject the null hypothesis (no jumps) and conclude that there is a jump.
    return test_stat > critical_value, test_stat, np.argmax(returns)

# %%
def get_price_data(tickers, start_date, end_date, interval):
    stock_data = {}
    for ticker in tickers:
        try:
            stock_data[ticker] = yf.download(ticker, start=start_date, end=end_date, progress=False, interval=interval)
        except:
            print("Error: Could not download data for ticker " + ticker)
            return None
    return stock_data

# %%
def get_return_data(tickers, yesterday_data, today_data):
    return_data = {}
    for ticker in tickers:
        price_data = yesterday_data[ticker]['Close'].values
        np.append(price_data, today_data[ticker]['Close'].values[0])
        returns = np.diff(np.log(price_data))
        return_data[ticker] = returns
    return return_data

# %%
def get_BNS_test_data(tickers, returns):
    bns_test_data = {}
    for ticker in tickers:
        bns_test_data[ticker] = bns_jump_test(returns[ticker])
    return bns_test_data

# %%
def get_overnight_jumps(data, returns):
    overnight_jumps = []
    for key, value in data.items():
        is_jump, test_stat, jump_index = value
        if is_jump:
            if jump_index == len(returns[key]) - 1:
                print(f"{key} jumped at the end of the day with a test statistic of {test_stat}")
                overnight_jumps.append((key, test_stat, returns[key][len(returns[key])-1]))
    overnight_jumps.sort(key=lambda x: x[1], reverse=True)
    return overnight_jumps

# %%
def get_trades(overnight_jumps, today_data, today_date, portfolio):
    potential_trade_list = [None] * min(10, len(overnight_jumps))
    return_total = sum([abs(x[2]) for x in overnight_jumps])
    for i in range(min(10, len(overnight_jumps))):
        ticker, test_stat, jump = overnight_jumps[i]
        trade_weight = abs(jump) / return_total
        potential_trade_list[i] = (ticker, trade_weight, jump)

    trade_list = [None] * len(potential_trade_list)
    for i in range(len(potential_trade_list)):
        ticker, trade_weight, jump = potential_trade_list[i]
        if jump < 0:
            # take a long postion
            sell_price = today_data[ticker]['Close'].values[0]
            buy_price = today_data[ticker]['Close'].values[2] 
            profit = (sell_price - buy_price) * trade_weight * portfolio / sell_price
            trade_list[i] = (ticker, profit)
        elif jump > 0:
            # take a short position
            buy_price = today_data[ticker]['Close'].values[0]
            sell_price = today_data[ticker]['Close'].values[2]
            profit = (sell_price - buy_price) * trade_weight * portfolio / sell_price
            trade_list[i] = (ticker, profit)
        else:
            print(f'Error: On {today_date}, {ticker} had a jump of 0.')
    return trade_list

# %%
# Create a trading day calendar
nyse = mcal.get_calendar('NYSE')

start_date = '2022-01-01'
end_date = '2022-6-31'
interval = "1h" 

portfolio = 10000
total_trades = {}


early = nyse.schedule(start_date=start_date, end_date=end_date, tz='America/New_York')

# TODO dataset of sp500 on minute intervals for the last ten years
sp500_tickers = ['MMM','AOS','AMZN','ABBV','ACN','ATVI','ADM','ADBE','ADP','AAP','AES','AFL','A','APD','AKAM','ALK','ALB','ARE','ALGN']

for i in range(1, len(early)-1):
    

    yesterday_date = early.iloc[i-1]['market_close'].date()
    today_date = early.iloc[i]['market_close'].date()
    tomorrow_date = early.iloc[i+1]['market_close'].date()

    

    
    yesterday_data = get_price_data(sp500_tickers, yesterday_date, today_date, interval)
    if yesterday_data == None:
        continue
    today_data = get_price_data(sp500_tickers, today_date, tomorrow_date, interval)
    if today_data == None:
        continue
    for ticker in sp500_tickers:
        if len(today_data[ticker]) != 7:
            print(f"Error: {ticker} data is missing for {yesterday_date}")
            continue

    returns = get_return_data(sp500_tickers, yesterday_data, today_data)

    bns_test_data = get_BNS_test_data(sp500_tickers, returns)

    overnight_jumps = get_overnight_jumps(bns_test_data, returns)

    trade_list = get_trades(overnight_jumps, today_data, today_date, portfolio)

    total_trades[today_date] = trade_list
    total_profit = sum([x[1] for x in trade_list])
    print(f"On {today_date}, the total return was {total_profit}.")
# Out:
# On 2022-01-04, the total return was 0.
# On 2022-01-05, the total return was 0.
# ADBE jumped at the end of the day with a test statistic of 4.593757360089037
# On 2022-01-06, the total return was 40.96712918590703.
# On 2022-01-07, the total return was 0.
# On 2022-01-10, the total return was 0.
# On 2022-01-11, the total return was 0.
# On 2022-01-12, the total return was 0.
# On 2022-01-13, the total return was 0.
# On 2022-01-14, the total return was 0.
# On 2022-01-18, the total return was 0.
# On 2022-01-19, the total return was 0.
# On 2022-01-20, the total return was 0.
# On 2022-01-21, the total return was 0.
# ABBV jumped at the end of the day with a test statistic of 2.6212144262568446
# On 2022-01-24, the total return was 233.83206455357725.
# On 2022-01-25, the total return was 0.
# On 2022-01-26, the total return was 0.
# On 2022-01-27, the total return was 0.
# On 2022-01-28, the total return was 0.
# On 2022-01-31, the total return was 0.
# On 2022-02-01, the total return was 0.
# On 2022-02-02, the total return was 0.
# On 2022-02-03, the total return was 0.
# On 2022-02-04, the total return was 0.
# On 2022-02-07, the total return was 0.
# On 2022-02-08, the total return was 0.
# On 2022-02-09, the total return was 0.
# On 2022-02-10, the total return was 0.
# On 2022-02-11, the total return was 0.
# ACN jumped at the end of the day with a test statistic of 2.6039004330017055
# ALGN jumped at the end of the day with a test statistic of 4.291464813641139
# On 2022-02-14, the total return was -53.93722292086484.
# ABBV jumped at the end of the day with a test statistic of 2.4484101940000618
# On 2022-02-15, the total return was 13.107231829899877.
# On 2022-02-16, the total return was 0.
# On 2022-02-17, the total return was 0.
# On 2022-02-18, the total return was 0.
# On 2022-02-22, the total return was 0.
# On 2022-02-23, the total return was 0.
# AAP jumped at the end of the day with a test statistic of 2.5516441490523545
# On 2022-02-24, the total return was 91.07625960914798.
# A jumped at the end of the day with a test statistic of 5.222504470962808
# On 2022-02-25, the total return was 104.90561431308963.
# On 2022-02-28, the total return was 0.
# On 2022-03-01, the total return was 0.
# On 2022-03-02, the total return was 0.
# On 2022-03-03, the total return was 0.
# On 2022-03-04, the total return was 0.
# On 2022-03-07, the total return was 0.
# ATVI jumped at the end of the day with a test statistic of 4.112565980430409
# On 2022-03-08, the total return was -84.53509255809684.
# On 2022-03-09, the total return was 0.
# On 2022-03-10, the total return was 0.
# On 2022-03-11, the total return was 0.
# On 2022-03-14, the total return was 0.
# On 2022-03-15, the total return was 0.
# On 2022-03-16, the total return was 0.
# On 2022-03-17, the total return was 0.
# AMZN jumped at the end of the day with a test statistic of 4.466958106788536
# On 2022-03-18, the total return was 111.19384420734559.
# AAP jumped at the end of the day with a test statistic of 2.7198189012767484
# On 2022-03-21, the total return was 45.150770475476996.
# On 2022-03-22, the total return was 0.
# On 2022-03-23, the total return was 0.
# On 2022-03-24, the total return was 0.
# On 2022-03-25, the total return was 0.
# On 2022-03-28, the total return was 0.
# On 2022-03-29, the total return was 0.
# On 2022-03-30, the total return was 0.
# On 2022-03-31, the total return was 0.
# On 2022-04-01, the total return was 0.
# On 2022-04-04, the total return was 0.
# AMZN jumped at the end of the day with a test statistic of 2.37562832490981
# On 2022-04-05, the total return was -70.49685051212116.
# On 2022-04-06, the total return was 0.
# ARE jumped at the end of the day with a test statistic of 2.557582662426828
# On 2022-04-07, the total return was -30.533999571648035.
# On 2022-04-08, the total return was 0.
# On 2022-04-11, the total return was 0.
# On 2022-04-12, the total return was 0.
# ADBE jumped at the end of the day with a test statistic of 2.4944916719919634
# A jumped at the end of the day with a test statistic of 3.392830964331476
# On 2022-04-13, the total return was 93.96476684250177.
# On 2022-04-14, the total return was 0.
# On 2022-04-18, the total return was 0.
# On 2022-04-19, the total return was 0.
# On 2022-04-20, the total return was 0.
# On 2022-04-21, the total return was 0.
# On 2022-04-22, the total return was 0.
# On 2022-04-25, the total return was 0.
# On 2022-04-26, the total return was 0.
# On 2022-04-27, the total return was 0.
# On 2022-04-28, the total return was 0.
# On 2022-04-29, the total return was 0.
# On 2022-05-02, the total return was 0.
# On 2022-05-03, the total return was 0.
# On 2022-05-04, the total return was 0.
# On 2022-05-05, the total return was 0.
# On 2022-05-06, the total return was 0.
# On 2022-05-09, the total return was 0.
# On 2022-05-10, the total return was 0.
# On 2022-05-11, the total return was 0.
# ADBE jumped at the end of the day with a test statistic of 4.631973238101215
# On 2022-05-12, the total return was -162.61637088604164.
# ABBV jumped at the end of the day with a test statistic of 2.39936940218713
# On 2022-05-13, the total return was -35.89395464943969.
# On 2022-05-16, the total return was 0.
# On 2022-05-17, the total return was 0.
# On 2022-05-18, the total return was 0.
# AOS jumped at the end of the day with a test statistic of 3.0078363018190197
# ACN jumped at the end of the day with a test statistic of 2.3264122034828754
# ARE jumped at the end of the day with a test statistic of 2.8190953996618298
# On 2022-05-19, the total return was 118.18842048838252.
# On 2022-05-20, the total return was 0.
# On 2022-05-23, the total return was 0.
# On 2022-05-24, the total return was 0.
# On 2022-05-25, the total return was 0.
# On 2022-05-26, the total return was 0.
# On 2022-05-27, the total return was 0.
# On 2022-05-31, the total return was 0.
# On 2022-06-01, the total return was 0.
# On 2022-06-02, the total return was 0.
# ATVI jumped at the end of the day with a test statistic of 2.5061878737070487
# On 2022-06-03, the total return was 13.471468002400453.
# On 2022-06-06, the total return was 0.
# On 2022-06-07, the total return was 0.
# APD jumped at the end of the day with a test statistic of 3.608513726422918
# On 2022-06-08, the total return was -173.1295580401742.
# On 2022-06-09, the total return was 0.
# On 2022-06-10, the total return was 0.
# On 2022-06-13, the total return was 0.
# ARE jumped at the end of the day with a test statistic of 6.195859749991205
# On 2022-06-14, the total return was -97.41032969728008.
# On 2022-06-15, the total return was 0.
# On 2022-06-16, the total return was 0.
# On 2022-06-17, the total return was 0.
# On 2022-06-21, the total return was 0.
# On 2022-06-22, the total return was 0.
# On 2022-06-23, the total return was 0.
# AOS jumped at the end of the day with a test statistic of 2.8437392483952384
# ADM jumped at the end of the day with a test statistic of 3.0676338674991563
# On 2022-06-24, the total return was 52.22902054057164.
# On 2022-06-27, the total return was 0.
# On 2022-06-28, the total return was 0.
# AOS jumped at the end of the day with a test statistic of 2.9531483582119886
# ACN jumped at the end of the day with a test statistic of 3.271882848793406
# AAP jumped at the end of the day with a test statistic of 2.3930536062105108
# APD jumped at the end of the day with a test statistic of 2.4754221231746856
# AKAM jumped at the end of the day with a test statistic of 3.9897354788206907
# On 2022-06-29, the total return was -1.2242125300780966.
# On 2022-06-30, the total return was 0.
# On 2022-07-01, the total return was 0.
# AKAM jumped at the end of the day with a test statistic of 2.4031594293769563
# On 2022-07-05, the total return was 51.22629108480926.
# On 2022-07-06, the total return was 0.
# On 2022-07-07, the total return was 0.
# On 2022-07-08, the total return was 0.
# On 2022-07-11, the total return was 0.
# On 2022-07-12, the total return was 0.
# On 2022-07-13, the total return was 0.
# On 2022-07-14, the total return was 0.
# AAP jumped at the end of the day with a test statistic of 3.7481780367851996
# On 2022-07-15, the total return was -13.787691400409965.
# On 2022-07-18, the total return was 0.
# On 2022-07-19, the total return was 0.
# On 2022-07-20, the total return was 0.
# On 2022-07-21, the total return was 0.
# On 2022-07-22, the total return was 0.
# On 2022-07-25, the total return was 0.
# ALB jumped at the end of the day with a test statistic of 2.836381347260299
# On 2022-07-26, the total return was 11.716046267825027.
# On 2022-07-27, the total return was 0.
# On 2022-07-28, the total return was 0.
# On 2022-07-29, the total return was 0.
# On 2022-08-01, the total return was 0.
# On 2022-08-02, the total return was 0.
# On 2022-08-03, the total return was 0.
# On 2022-08-04, the total return was 0.
# On 2022-08-05, the total return was 0.
# On 2022-08-08, the total return was 0.
# On 2022-08-09, the total return was 0.
# On 2022-08-10, the total return was 0.
# On 2022-08-11, the total return was 0.
# A jumped at the end of the day with a test statistic of 3.3493678555753807
# On 2022-08-12, the total return was 9.313043558372641.
# AOS jumped at the end of the day with a test statistic of 3.321715370897517
# AMZN jumped at the end of the day with a test statistic of 3.23360685442717
# AAP jumped at the end of the day with a test statistic of 2.511356916610592
# ALK jumped at the end of the day with a test statistic of 2.599692463806836
# On 2022-08-15, the total return was 51.03760540680645.
# On 2022-08-16, the total return was 0.
# On 2022-08-17, the total return was 0.
# On 2022-08-18, the total return was 0.
# On 2022-08-19, the total return was 0.
# On 2022-08-22, the total return was 0.
# AKAM jumped at the end of the day with a test statistic of 5.156731848586302
# On 2022-08-23, the total return was 79.43232520064532.
# On 2022-08-24, the total return was 0.
# On 2022-08-25, the total return was 0.
# On 2022-08-26, the total return was 0.
# On 2022-08-29, the total return was 0.
# On 2022-08-30, the total return was 0.
# On 2022-08-31, the total return was 0.
# On 2022-09-01, the total return was 0.
# On 2022-09-02, the total return was 0.
# AKAM jumped at the end of the day with a test statistic of 2.523645652275646
# On 2022-09-06, the total return was 19.759842706896872.
# On 2022-09-07, the total return was 0.
# On 2022-09-08, the total return was 0.
# On 2022-09-09, the total return was 0.
# On 2022-09-12, the total return was 0.
# On 2022-09-13, the total return was 0.
# On 2022-09-14, the total return was 0.
# On 2022-09-15, the total return was 0.
# On 2022-09-16, the total return was 0.
# ADP jumped at the end of the day with a test statistic of 4.57696342701557
# ALK jumped at the end of the day with a test statistic of 2.586660143697107
# On 2022-09-19, the total return was 5.144701901349636.
# On 2022-09-20, the total return was 0.
# On 2022-09-21, the total return was 0.
# On 2022-09-22, the total return was 0.
# On 2022-09-23, the total return was 0.
# ALB jumped at the end of the day with a test statistic of 4.0931383987498755
# On 2022-09-26, the total return was -255.44656202645882.
# On 2022-09-27, the total return was 0.
# ADM jumped at the end of the day with a test statistic of 2.916221781341517
# On 2022-09-28, the total return was -129.44163713447801.
# On 2022-09-29, the total return was 0.
# On 2022-09-30, the total return was 0.
# On 2022-10-03, the total return was 0.
# On 2022-10-04, the total return was 0.
# On 2022-10-05, the total return was 0.
# On 2022-10-06, the total return was 0.
# On 2022-10-07, the total return was 0.
# MMM jumped at the end of the day with a test statistic of 2.449956339062299
# ACN jumped at the end of the day with a test statistic of 2.379096399319016
# A jumped at the end of the day with a test statistic of 3.1749490469069555
# ALGN jumped at the end of the day with a test statistic of 2.501779912613734
# On 2022-10-10, the total return was -107.8224841931627.
# On 2022-10-11, the total return was 0.
# On 2022-10-12, the total return was 0.
# On 2022-10-13, the total return was 0.
# On 2022-10-14, the total return was 0.
# On 2022-10-17, the total return was 0.
# On 2022-10-18, the total return was 0.
# On 2022-10-19, the total return was 0.
# On 2022-10-20, the total return was 0.
# MMM jumped at the end of the day with a test statistic of 2.6681955815403104
# AOS jumped at the end of the day with a test statistic of 3.8484765001927568
# AMZN jumped at the end of the day with a test statistic of 2.533815418010497
# ADP jumped at the end of the day with a test statistic of 2.78822469554729
# A jumped at the end of the day with a test statistic of 3.7530594974832305
# ALGN jumped at the end of the day with a test statistic of 3.233302893580943
# On 2022-10-21, the total return was -4.611804495699452.
# On 2022-10-24, the total return was 0.
# AAP jumped at the end of the day with a test statistic of 2.3978010576998465
# On 2022-10-25, the total return was -43.64484208265079.
# On 2022-10-26, the total return was 0.
# On 2022-10-27, the total return was 0.
# On 2022-10-28, the total return was 0.
# ALK jumped at the end of the day with a test statistic of 6.917674659432545
# On 2022-10-31, the total return was 9.011244892396146.
# On 2022-11-01, the total return was 0.
# On 2022-11-02, the total return was 0.
# On 2022-11-03, the total return was 0.
# On 2022-11-04, the total return was 0.
# On 2022-11-07, the total return was 0.
# On 2022-11-08, the total return was 0.
# On 2022-11-09, the total return was 0.
# On 2022-11-10, the total return was 0.
# On 2022-11-11, the total return was 0.
# On 2022-11-14, the total return was 0.
# On 2022-11-15, the total return was 0.
# On 2022-11-16, the total return was 0.
# ABBV jumped at the end of the day with a test statistic of 3.6763200459535104
# On 2022-11-17, the total return was -85.57169393915838.
# On 2022-11-18, the total return was 0.
# On 2022-11-21, the total return was 0.
# On 2022-11-22, the total return was 0.
# On 2022-11-23, the total return was 0.
# Error: MMM data is missing for 2022-11-23
# Error: AOS data is missing for 2022-11-23
# Error: AMZN data is missing for 2022-11-23
# Error: ABBV data is missing for 2022-11-23
# Error: ACN data is missing for 2022-11-23
# Error: ATVI data is missing for 2022-11-23
# Error: ADM data is missing for 2022-11-23
# Error: ADBE data is missing for 2022-11-23
# Error: ADP data is missing for 2022-11-23
# Error: AAP data is missing for 2022-11-23
# Error: AES data is missing for 2022-11-23
# Error: AFL data is missing for 2022-11-23
# Error: A data is missing for 2022-11-23
# Error: APD data is missing for 2022-11-23
# Error: AKAM data is missing for 2022-11-23
# Error: ALK data is missing for 2022-11-23
# Error: ALB data is missing for 2022-11-23
# Error: ARE data is missing for 2022-11-23
# Error: ALGN data is missing for 2022-11-23
# On 2022-11-25, the total return was 0.
# On 2022-11-28, the total return was 0.
# MMM jumped at the end of the day with a test statistic of 2.5400817091558587
# AOS jumped at the end of the day with a test statistic of 3.034965976106327
# ADP jumped at the end of the day with a test statistic of 2.513610067633134
# AFL jumped at the end of the day with a test statistic of 3.153580277761262
# ALK jumped at the end of the day with a test statistic of 4.938975016950856
# On 2022-11-29, the total return was -21.111637449478913.
# On 2022-11-30, the total return was 0.
# On 2022-12-01, the total return was 0.
# On 2022-12-02, the total return was 0.
# On 2022-12-05, the total return was 0.
# ALGN jumped at the end of the day with a test statistic of 3.4269064109051697
# On 2022-12-06, the total return was 56.49733749123348.
# On 2022-12-07, the total return was 0.
# On 2022-12-08, the total return was 0.
# MMM jumped at the end of the day with a test statistic of 2.5825743579463016
# On 2022-12-09, the total return was 33.8236698234665.
# On 2022-12-12, the total return was 0.
# On 2022-12-13, the total return was 0.
# On 2022-12-14, the total return was 0.
# A jumped at the end of the day with a test statistic of 3.323215528778889
# On 2022-12-15, the total return was -44.2727382410951.
# On 2022-12-16, the total return was 0.
# On 2022-12-19, the total return was 0.
# On 2022-12-20, the total return was 0.
# On 2022-12-21, the total return was 0.
# On 2022-12-22, the total return was 0.
# On 2022-12-23, the total return was 0.
# AES jumped at the end of the day with a test statistic of 2.958309790789801
# On 2022-12-27, the total return was -48.771778442966955.
# On 2022-12-28, the total return was 0.
# On 2022-12-29, the total return was 0.

# %%
total_profits = 0
for key, value in total_trades.items():
    if len(value) > 0:
        print(f"On {key}, the trades were {value}.")
        for trade in value:
            total_profits += trade[1]
# Out:
# On 2022-01-06, the trades were [('ADBE', 40.96712918590703)].
# On 2022-01-24, the trades were [('ABBV', 233.83206455357725)].
# On 2022-02-14, the trades were [('ALGN', -74.09353125869906), ('ACN', 20.156308337834222)].
# On 2022-02-15, the trades were [('ABBV', 13.107231829899877)].
# On 2022-02-24, the trades were [('AAP', 91.07625960914798)].
# On 2022-02-25, the trades were [('A', 104.90561431308963)].
# On 2022-03-08, the trades were [('ATVI', -84.53509255809684)].
# On 2022-03-18, the trades were [('AMZN', 111.19384420734559)].
# On 2022-03-21, the trades were [('AAP', 45.150770475476996)].
# On 2022-04-05, the trades were [('AMZN', -70.49685051212116)].
# On 2022-04-07, the trades were [('ARE', -30.533999571648035)].
# On 2022-04-13, the trades were [('A', 81.23131855361196), ('ADBE', 12.733448288889821)].
# On 2022-05-12, the trades were [('ADBE', -162.61637088604164)].
# On 2022-05-13, the trades were [('ABBV', -35.89395464943969)].
# On 2022-05-19, the trades were [('AOS', 6.81313178903892), ('ARE', 2.2363081587257954), ('ACN', 109.13898054061781)].
# On 2022-06-03, the trades were [('ATVI', 13.471468002400453)].
# On 2022-06-08, the trades were [('APD', -173.1295580401742)].
# On 2022-06-14, the trades were [('ARE', -97.41032969728008)].
# On 2022-06-24, the trades were [('ADM', -2.002677688328891), ('AOS', 54.23169822890053)].
# On 2022-06-29, the trades were [('AKAM', 2.614653467199821), ('ACN', 4.108954517567239), ('AOS', -21.172357900386814), ('APD', 0.40894910360380937), ('AAP', 12.815588281937847)].
# On 2022-07-05, the trades were [('AKAM', 51.22629108480926)].
# On 2022-07-15, the trades were [('AAP', -13.787691400409965)].
# On 2022-07-26, the trades were [('ALB', 11.716046267825027)].
# On 2022-08-12, the trades were [('A', 9.313043558372641)].
# On 2022-08-15, the trades were [('AOS', 12.872369729953492), ('AMZN', 11.548296704922354), ('ALK', 34.176314395482954), ('AAP', -7.559375423552353)].
# On 2022-08-23, the trades were [('AKAM', 79.43232520064532)].
# On 2022-09-06, the trades were [('AKAM', 19.759842706896872)].
# On 2022-09-19, the trades were [('ADP', -0.37965920056458513), ('ALK', 5.524361101914222)].
# On 2022-09-26, the trades were [('ALB', -255.44656202645882)].
# On 2022-09-28, the trades were [('ADM', -129.44163713447801)].
# On 2022-10-10, the trades were [('A', -21.68125323665588), ('ALGN', -21.8442004420163), ('MMM', -30.62660143155774), ('ACN', -33.67042908293278)].
# On 2022-10-21, the trades were [('AOS', -6.2580687029984645), ('A', -14.050813710474253), ('ALGN', -15.819860211432452), ('ADP', 12.017804724573988), ('MMM', 5.896269287420518), ('AMZN', 13.602864117211212)].
# On 2022-10-25, the trades were [('AAP', -43.64484208265079)].
# On 2022-10-31, the trades were [('ALK', 9.011244892396146)].
# On 2022-11-17, the trades were [('ABBV', -85.57169393915838)].
# On 2022-11-29, the trades were [('ALK', 1.5929475913187623), ('AFL', -7.672722719215502), ('AOS', -1.5548203017448419), ('MMM', -7.289018612640896), ('ADP', -6.188023407196435)].
# On 2022-12-06, the trades were [('ALGN', 56.49733749123348)].
# On 2022-12-09, the trades were [('MMM', 33.8236698234665)].
# On 2022-12-15, the trades were [('A', -44.2727382410951)].
# On 2022-12-27, the trades were [('AES', -48.771778442966955)].

# %%
print(f"The total profits were {total_profits}.")
print(f"The total return was {total_profits / portfolio}%.")
print(f"The total return of the S&P 500 was -18.11%") #TODO: create function to calc return of S&P 500
print(f"Our strategy beats the S&P 500 by {total_profits / portfolio - (-18.11)}%.")
# Out:
# The total profits were -219.2117623892016.
# The total return was -0.02192117623892016%.
# The total return of the S&P 500 was -18.11%
# Our strategy beats the S&P 500 by 18.08807882376108%.
